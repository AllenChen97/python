# %% [markdown]
# # 标记Markers

# %% [markdown]
# |Markers|描述|
# |:-----:|:-----:|
# | "." |         point marker
# | "," |         pixel marker
# | "o" |         circle marker
# | "v" |         triangle_down marker
# | "^" |         triangle_up marker
# | "<" |         triangle_left marker
# | ">" |         triangle_right marker
# | "1" |         tri_down marker
# | "2" |         tri_up marker
# | "3" |         tri_left marker
# | "4" |         tri_right marker
# | "s" |         square marker
# | "p" |         pentagon marker
# | "*" |         star marker
# | "h" |         hexagon1 marker
# | "H" |         hexagon2 marker
# | "+" |         plus marker
# | "x" |         x marker
# | "D" |         diamond marker
# | "d" |         thin_diamond marker
# | $"|"$ |         vline marker
# | "_" |         hline marker

# %% [markdown]
# # 线条风格

# %% [markdown]
# |线型|描述 |
# | :--------: | :---------: |
# |'-'|        实线样式（solid line style）|
# |'--'|        虚线样式（dashed line style）|
# |'-.'|        点划线样式（dash-dot line style）|
# |':'|         点虚线样式（dotted line style）|

# %% [markdown]
# # 图形颜色
#
# |color|颜色 |
# | :--------: | :---------: |
# | b |蓝色|
# | g |绿色|
# | r |红色|
# | c |青色|
# | m |洋红色|
# | y |黄色|
# | k |黑色|
# | w |白色|
#
# RGB颜色对照表：http://tool.oschina.net/commons?type=3

# %% [markdown]
# # cmap参数

# %% [markdown]
# ![wNCIFBv4ob9KgAAAABJRU5ErkJggg==.png](attachment:wNCIFBv4ob9KgAAAABJRU5ErkJggg==.png)

# %% [markdown]
# ![%E4%B8%8B%E8%BD%BD.png](attachment:%E4%B8%8B%E8%BD%BD.png)
