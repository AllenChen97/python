# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#数据类型简介" data-toc-modified-id="数据类型简介-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>数据类型简介</a></span></li><li><span><a href="#布尔型" data-toc-modified-id="布尔型-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>布尔型</a></span><ul class="toc-item"><li><span><a href="#True和False" data-toc-modified-id="True和False-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>True和False</a></span></li><li><span><a href="#逻辑运算符" data-toc-modified-id="逻辑运算符-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>逻辑运算符</a></span></li><li><span><a href="#练习1" data-toc-modified-id="练习1-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>练习1</a></span></li></ul></li><li><span><a href="#数字类型" data-toc-modified-id="数字类型-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>数字类型</a></span><ul class="toc-item"><li><span><a href="#数字类型分类" data-toc-modified-id="数字类型分类-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>数字类型分类</a></span><ul class="toc-item"><li><span><a href="#整型int" data-toc-modified-id="整型int-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>整型int</a></span></li><li><span><a href="#浮点型float" data-toc-modified-id="浮点型float-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>浮点型float</a></span></li><li><span><a href="#复数型" data-toc-modified-id="复数型-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>复数型</a></span></li></ul></li><li><span><a href="#数字类型转换" data-toc-modified-id="数字类型转换-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>数字类型转换</a></span></li><li><span><a href="#数字类型的运算符" data-toc-modified-id="数字类型的运算符-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>数字类型的运算符</a></span><ul class="toc-item"><li><span><a href="#比较运算符" data-toc-modified-id="比较运算符-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>比较运算符</a></span></li><li><span><a href="#复合赋值运算符" data-toc-modified-id="复合赋值运算符-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>复合赋值运算符</a></span></li><li><span><a href="#练习2" data-toc-modified-id="练习2-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>练习2</a></span></li><li><span><a href="#与数字相关的BIF" data-toc-modified-id="与数字相关的BIF-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>与数字相关的BIF</a></span></li><li><span><a href="#math科学计算库" data-toc-modified-id="math科学计算库-3.3.5"><span class="toc-item-num">3.3.5&nbsp;&nbsp;</span>math科学计算库</a></span></li></ul></li></ul></li><li><span><a href="#字符串" data-toc-modified-id="字符串-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>字符串</a></span></li><li><span><a href="#获得类型信息" data-toc-modified-id="获得类型信息-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>获得类型信息</a></span></li></ul></div>

# %% [markdown]
# <img width = '500' height ='400' src ="https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1547816761910&di=d4f6dd69360455bd74531b7e7352ee2f&imgtype=0&src=http%3A%2F%2Fimages.cnblogs.com%2Fcnblogs_com%2FFrank99%2F1215494%2Fo_%25e8%2583%258c%25e6%2599%25af5.gif"/>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 数据类型简介

# %% [markdown]
# 类型的作用：编程语言对数据的一种划分，数据从不同角度看有不同的含义。
# 程序设计语言不允许存在语法歧义，因此，需要明确说明数据的含义， 这就是“类型” 的作用。

# %% [markdown]
# **<font color=#000000 size=3.3 face="黑体">
# Python中常用的数据类型有：**
# <font color=#00008B size=2.9 face="黑体">
#
# - 数字(Numbers)：        整数, 浮点数, 复数
#
# - 布尔(Booleans)：       True和False
#
# - 字符串(Strings)：      Uniconde字符序列, 在引号内包含
#
# - 列表(list)：           有序的值的序列
#
# - 元组(Tuples)：         有序的值的序列且不可改变
#
# - 字典(Dictionaries)：   无序的键值对的组合
#
# - 集合(Sets)：           无序的不含重复值的序列

# %% [markdown]
# ![_auto_1](attachment:_auto_1)

# %% [markdown]
# #  布尔型

# %% [markdown]
# ## True和False
# - 布尔类型数据可以运算，但是不是用来运算的，而是用来判断真假的。
# - 如果布尔类型运算的时候，可以把True当做1，把False当做0。

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
True /False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-a8b7d1284074> in <module>()
# ----> 1 True /False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## 逻辑运算符

# %% [markdown]
# | 运算符 | 逻辑表达式 | 描述 | 实例 |
# | :--- | :--- | :--- | :--- |
# | and	| x and y	| 布尔"与" - 如果 x 为 False，x and y 返回 False，否则它返回 y 的计算值。	| (a and b) 返回 20。|
# |or |	x or y	| 布尔"或" - 如果 x 是 True，它返回 x 的值，否则它返回 y 的计算值。	| (a or b) 返回 10。 |
# |not|	not x	| 布尔"非" - 如果 x 为 True，返回 False 。如果 x 为 False，它返回 True。 |	not(a and b) 返回 False |

# %% [markdown]
# 对于初学者来说，记忆逻辑运算符的运算规则是比较棘手的问题。
# 由于逻辑运算符涉及布尔类型数值的知识，因此，在这里对布尔类型知识进行扩充。
# &ensp;
#
#
# &ensp;
# <font color=#00008B size=3.5 face="黑体">
# **（1）not运算符**
# <font color=#DC143C size=2.5 face="黑体">
# - 我们可以使用not逻辑运算符进行真值测试
# - 以下情况将会被视作False：
#     - False 、None、0、0.0、虚数0
#     - 空字符串、空元组、空列表、空字典、空集合

# %%
not 0
# Out:
# True

# %%
not "abc"
# Out:
# False

# %%
not False
not None 
not 0
not 0.0
not 0+0j
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# &ensp;
#
#
# &ensp;
# <font color=#00008B size=3.5 face="黑体">
# **（2）对于and运算符**
# <font color=#DC143C size=2.5 face="黑体">
# - and逻辑判断语句从左读到右，比如A and B
# - 从左到右读，一旦遇到False，则返回遇到的第一个False
# - 从左到右读，全都是True，则返回最后一个True
# - 记忆法：and会抓出来第一个False，实在没有False，抓最后一个True

# %%
True and False

True and False and True
# Out:
# False
# False

# %%
not 1
# Out:
# False

# %%
1 and [] and 0 and 3
# Out:
# []

# %% [markdown]
# &ensp;
#
#
#
# &ensp;
# &ensp;
#
#
#
# &ensp;
# <font color=#00008B size=3.5 face="黑体">
# **（3）对于or运算符**
# <font color=#DC143C size=2.5 face="黑体">
# - or逻辑判断语句从左读到右，比如A or B
# - 从左到右读，一旦遇到True，则返回遇到的第一个True
# - 从左到右读，全都是False，则返回最后一个False
# - 记忆法：or会抓出来第一个True，实在没有True，抓最后一个False

# %%
False or True

False or True or False

0 or 1

0 or 2 or 1 or 0
# Out:
# True
# True
# 1
# 2

# %%
0 or [] or ()
# Out:
# ()

# %% [markdown]
# &ensp;
#
#
# &ensp;
# <font color=#00008B size=3.5 face="黑体">
# **（4）逻辑运算符优先级问题**
# <font color=#DC143C size=3 face="黑体">
# - 优先级顺序：or<and<not
# - 先处理not，然后处理and，最后处理or

# %%
1 and 2 and 3 or 4  or not []
# Out:
# 3

# %%
(1 and 2 and 3) or 4  or  (not [])
# Out:
# 3

# %% [markdown]
# &ensp;
# &emsp;
# ## 练习1

# %% [markdown]
# 猜一猜：0 or 0 or 0 and 5 or not 0 or 10

# %%
0 or 0 or 0 and 5 or not 0 or 10
# Out:
# True

# %% [markdown]
# not: 最优先
# and: 取第一个 False；确实True的话取最后一个True
# or：取第一个True；全是False的话取最后一个False

# %% [markdown]
# &ensp;
#
# &emsp;
# &ensp;
# &emsp;
# # 数字类型

# %% [markdown]
# int 整数型 </br>
# <br/>float浮点型</br>
# <br/>complex复数</br>

# %% [markdown]
# ## 数字类型分类

# %% [markdown]
# ### 整型int

# %%
a = 256
type(a)
# Out:
# int

# %% [markdown]
# &ensp;
# &emsp;
# ### 浮点型float

# %%
a = 1.0
type(a)
# Out:
# float

# %%
1.0+2
# Out:
# 3.0

# %%
type(1.0+1.0)
type(1.0+1)
# Out:
# float
# float

# %% [markdown]
# 科学计数法使用字母“e” 或者“E” 作为幂的符号，以10为基数

# %%
2.1e2   #2.1*10**2
# Out:
# 210.0

# %%
2.1*10**2
# Out:
# 210.0

# %% [markdown]
# &ensp;
#
# &emsp;
# ### 复数型

# %% [markdown]
# 与数学中的复数概念一致, z = a + bj， a是实数部分， b是虚数部分， a和b都是浮点类型，虚数部分用j或者J标识

# %%
a = 3 + 4j
a
# Out:
# (3+4j)

# %%
a=1.0
b = 2+1j
a+b
# Out:
# (3+1j)

# %%
a = complex(1,3)
b=complex(1,3)
a+b
# Out:
# (2+6j)

# %% [markdown]
# 对于复数z，可以用z.real获得实数部分， z.imag获得虚数部分

# %%
a.real
a.imag
# Out:
# 1.0
# 3.0

# %% [markdown]
# &ensp;
#
#
# &ensp;
# ## 数字类型转换

# %% [markdown]
# &ensp;
# &ensp;
# <font color=#00008B size=4 face="黑体">
# **（1）int(x)**
# <font color=#000000 size=2.5 face="黑体">
# - 将x转换成整数类型
# - 如果x是浮点型，<font color=#DC143C size=2.5 face="黑体">小数点后面的数字都会砍掉，注意不是四舍五入。
# <font color=#000000 size=2.5 face="黑体">
# - 如果想四舍五入，可以用round(x)

# %%
a=12.1

b=int(a)
#转换结果如何？
a
b
type(b)
# Out:
# 12.1
# 12
# int

# %% [markdown]
# 支持 float、str转换为int类型。

# %% [markdown]
# &ensp;
#
#
# &ensp;
# <font color=#00008B size=4 face="黑体">
# **（2） float(x)**
# <font color=#000000 size=2.5 face="黑体">
# ——将x转换成浮点数类型

# %% [markdown]
# 支持转换为 float 类型的，仅有 int、str、bytes，其他类型均不支持。

# %%
a=123
b=float(a)

#转换结果如何？
a
b
type(b)
# Out:
# 123
# 123.0
# float

# %% [markdown]
# &ensp;
#
#
# &ensp;
# <font color=#00008B size=4 face="黑体">
# **（3） complex(x)**
# <font color=#000000 size=2.5 face="黑体">
# ——将x转换成复数类型

# %%
a=complex(12) 
a
# Out:
# (12+0j)

# %% [markdown]
# &ensp;
#
# &emsp;
# &ensp;
#
# &emsp;
# ## 数字类型的运算符

# %% [markdown]
# 下面以a=10 ,b=20为例进行计算
#
# | 运算符 | 描述   | 实例                                                         |
# | ------ | ------ | ------------------------------------------------------------ |
# | +      | 加     | 两个对象相加 a + b 输出结果 30                               |
# | -      | 减     | 得到负数或是一个数减去另一个数 a - b 输出结果 -10            |
# | *      | 乘     | 两个数相乘或是返回一个被重复若干次的字符串 a * b 输出结果 200 |
# | /      | 除     | x除以y b / a 输出结果 2                                      |
# | //     | 取整除 | 返回商的整数部分 9//2 输出结果 4 , 9.0//2.0 输出结果 4.0     |
# | %      | 取余   | 返回除法的余数 b % a 输出结果 0                              |
# | **     | 幂     | 返回x的y次幂 a**b 为10的20次方， 输出结果 100000000000000000000 |
#
# - 乘除大于加减
# - 指数运算大于乘除

# %%
3 ** 3
# Out:
# 27

# %%
9 / 6
# Out:
# 1.5

# %%
10 % 2
# Out:
# 4

# %%
9 % 6
# Out:
# 3

# %% [markdown]
# &ensp;
#
# &emsp;

# %% [markdown]
# ### 比较运算符

# %% [markdown]
#   | 运算符 | 描述                                                         | 示例                                              |
#   | ------ | ------------------------------------------------------------ | ------------------------------------------------- |
#   | ==     | 检查两个操作数的值是否相等，如果是则条件变为真。             | 如a=3,b=3则（a == b) 为 true.                     |
#   | !=     | 检查两个操作数的值是否相等，如果值不相等，则条件变为真。     | 如a=1,b=3则(a != b) 为 true.                      |
#   | >      | 检查左操作数的值是否大于右操作数的值，如果是，则条件成立。   | 如a=7,b=3则(a > b) 为 true.                       |
#   | <      | 检查左操作数的值是否小于右操作数的值，如果是，则条件成立。   | 如a=7,b=3则(a < b) 为 false.                      |
#   | >=     | 检查左操作数的值是否大于或等于右操作数的值，如果是，则条件成立。 | 如a=3,b=3则(a >= b) 为 true.                      |
#   | <=     | 检查左操作数的值是否小于或等于右操作数的值，如果是，则条件成立。 | 如a=3,b=3则(a <= b) 为 true.                      |

# %%
a=2
b=3

a!=b
# Out:
# True

# %% [markdown]
# &ensp;
#
# &emsp;
# &ensp;
#
# &emsp;

# %% [markdown]
# &ensp;
# &emsp;
# ### 复合赋值运算符

# %% [markdown]
# | 运算符 | 描述             | 实例                      |
# | ------ | ---------------- | ------------------------- |
# | +=     | 加法赋值运算符   | c += a 等效于 c = c + a   |
# | -=     | 减法赋值运算符   | c -= a 等效于 c = c - a   |
# | *=     | 乘法赋值运算符   | c * = a 等效于 c = c * a   |
# | /=     | 除法赋值运算符   | c /= a 等效于 c = c / a   |
# | %=     | 取模赋值运算符   | c %= a 等效于 c = c % a   |
# | **=    | 幂赋值运算符     | c ** = a 等效于 c = c ** a |
# | //=    | 取整除赋值运算符 | c //= a 等效于 c = c // a |

# %%
a = 10
b = 20
a /= b
a
# Out:
# 0.5

# %%
a = 10
b = 20
a *= b    #相当于a=a*b，就是说a+b等于10*20，结果等于200，再将200重新赋值给a，a最后变成200
a
# Out:
# 200

# %%
a = 100
b = 2
a /= b
a
# Out:
# 50.0

# %% [markdown]
# &ensp;
#
# &emsp;
# ### 练习2

# %% [markdown]
# 尝试将以下公式用复合赋值的方式来写,自行代入数字来观察运算规律:
# - a = a/b
# - a = a**b
# - a = a // b
# - a = a % b

# %%
a=100 
a+=2
a
# Out:
# 102

# %%
a = 300
a //= 7
int(a)
# Out:
# 42

# %% [markdown]
# &ensp;
#
# &emsp;

# %% [markdown]
# &ensp;
#
# &emsp;
# ### 与数字相关的BIF

# %% [markdown]
# |.|python内置的一些计算函数：|
# | :---- | :-----: |
# | abs(x) | 返回x的绝对值，类型随x|
# | max(n1, n2, ...) | 返回最大值 |
# | min(n1, n2, ...) | 返回最小值 |
# | round(x [,n]) | 默认返回浮点数x的四舍五入值，如给出n值，则代表舍入到小数点后的n位。例如round(1.23456, 3)返回1.235 |
# | pow(x,y)|返回x的y次幂，即x**y|

# %%
abs(-9)
# Out:
# 9

# %%
max(1,2,3,4,5)
# Out:
# 5

# %%
round(3.1415926,3)
# Out:
# 3.142

# %% [markdown]
# &ensp;
#
#
# &ensp;
# **返回x的y次幂**

# %%
pow(3,2)
# Out:
# 9

# %% [markdown]
# &ensp;
#
# &emsp;
#
# ### math科学计算库

# %% [markdown]
# |.. |python还提供科学计算等库，例如math，导入math库后，常用的函数有：|
# |----|-----|
# | fabs(x)|返回x的绝对值，类型是浮点数|
# |ceil(x)|取x的上入整数，如math.ceil(4.1)返回5|
# | floor(x)|取x的下入整数，如math.floor(4.9)返回4|
# | exp(x)|返回e的x次幂，e是自然常数|
# | sqrt(x)|返回x的平方根，返回值是float类型|
# | modf(x)|返回x的整数部分和小数部分，两部分的符号与x相同，整数部分以浮点型表示。例如math.modf(4.333)，返回元组(0.3330000000000002, 4.0)|
# |log10(x)|返回以10为基数的x的对数，返回值类型是浮点数|
# | log(x,y)|返回以y为基数的x的对数，返回值类型是浮点数|

# %% [markdown]
# - 使用math科学计算库中的方法（math库中的函数），需要先导入math库：
#     - 导入格式：import math
#         - 使用math中的方法时，math.$*$()
#     - 导入格式： from math import *
#         - 使用math中的方法时直接使用math库中的函数即可：

# %%
from math import*  
log(100,10)

log10(100)
# Out:
# 2.0
# 2.0

# %%
import math 
math.log(100,10)  #小心，是以10为基数
# Out:
# 2.0

# %% [markdown]
# &ensp;
#
#
# &ensp;
# **将弧度转换为角度**

# %%
pi=math.pi

math.degrees(pi)
# Out:
# 180.0

# %% [markdown]
# &ensp;
#
#
# &ensp;
# **e的2次幂**

# %%
math.exp(2)
# Out:
# 7.38905609893065

# %% [markdown]
# &ensp;
#
#
# &ensp;
# **返回x的平方根**

# %%
math.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# &ensp;
#
# &emsp;
# # 字符串

# %% [markdown]
# - 字符串就是连续的字符序列，是计算机所能表示的一切字符的集合。
# - 在Python中，字符串属于不可变序列。
# - 通常使用单引号“''”、双引号“""”、或者三引号“''' '''”或“""" """”括起来。
#     - 这三种引号形式在语义上没有差别，只是在形式上有些差别。
#     - 单引号和双引号的字符序列必须在同一行上
#     - 而三引号内的字符序列可以分布在多行。

# %%
a='我是字符串'

# %%
b="我也是字符串"

# %%
c=""""我还是字符串
字符串分布在多行""""

# %%
print(c)
# Out:
# 我还是字符串
# 字符串分布在多行

# %% [markdown]
# ```
#
#
#
# ```
# # 获得类型信息

# %% [markdown]
# 主要是type()和isinstance()函数。
# 可以对输入的数据类型进行判断。

# %%
aa = "ccl"
type(aa)
# Out:
# str

# %%
isinstance(aa,str)
# Out:
# True
