# %% [markdown]
# <h1>前言 python基础知识<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#前言" data-toc-modified-id="前言-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>前言</a></span><ul class="toc-item"><li><span><a href="#Python基础--如何学习" data-toc-modified-id="Python基础--如何学习-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Python基础--如何学习</a></span></li><li><span><a href="#为什么学习Python" data-toc-modified-id="为什么学习Python-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>为什么学习Python</a></span></li><li><span><a href="#为什么数据科学家喜欢用Python？" data-toc-modified-id="为什么数据科学家喜欢用Python？-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>为什么数据科学家喜欢用Python？</a></span></li></ul></li><li><span><a href="#基础知识" data-toc-modified-id="基础知识-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>基础知识</a></span><ul class="toc-item"><li><span><a href="#Python概述" data-toc-modified-id="Python概述-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Python概述</a></span><ul class="toc-item"><li><span><a href="#Python简史" data-toc-modified-id="Python简史-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Python简史</a></span></li><li><span><a href="#环境和版本问题" data-toc-modified-id="环境和版本问题-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>环境和版本问题</a></span></li><li><span><a href="#熟悉代码的运行" data-toc-modified-id="熟悉代码的运行-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>熟悉代码的运行</a></span></li><li><span><a href="#练习1" data-toc-modified-id="练习1-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>练习1</a></span></li></ul></li><li><span><a href="#代码格式" data-toc-modified-id="代码格式-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>代码格式</a></span><ul class="toc-item"><li><span><a href="#注释" data-toc-modified-id="注释-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>注释</a></span></li><li><span><a href="#练习2" data-toc-modified-id="练习2-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>练习2</a></span></li><li><span><a href="#缩进" data-toc-modified-id="缩进-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>缩进</a></span></li></ul></li><li><span><a href="#内置函数-BIF　" data-toc-modified-id="内置函数-BIF　-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>内置函数 BIF　</a></span><ul class="toc-item"><li><span><a href="#查看BIF帮助文档" data-toc-modified-id="查看BIF帮助文档-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>查看BIF帮助文档</a></span></li></ul></li></ul></li><li><span><a href="#变量" data-toc-modified-id="变量-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>变量</a></span><ul class="toc-item"><li><span><a href="#变量的属性" data-toc-modified-id="变量的属性-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>变量的属性</a></span></li><li><span><a href="#变量的内涵" data-toc-modified-id="变量的内涵-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>变量的内涵</a></span></li><li><span><a href="#变量的命名要点" data-toc-modified-id="变量的命名要点-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>变量的命名要点</a></span></li><li><span><a href="#变量赋值" data-toc-modified-id="变量赋值-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>变量赋值</a></span></li></ul></li><li><span><a href="#语句" data-toc-modified-id="语句-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>语句</a></span><ul class="toc-item"><li><span><a href="#print输出" data-toc-modified-id="print输出-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>print输出</a></span><ul class="toc-item"><li><span><a href="#中间分隔符：sep=&quot;-&quot;" data-toc-modified-id="中间分隔符：sep=&quot;-&quot;-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>中间分隔符：sep=" "</a></span></li><li><span><a href="#结尾换行符:end=''-&quot;" data-toc-modified-id="结尾换行符:end=''-&quot;-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>结尾换行符:end='' "</a></span></li><li><span><a href="#练习3" data-toc-modified-id="练习3-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>练习3</a></span></li></ul></li><li><span><a href="#获取输入-input" data-toc-modified-id="获取输入-input-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>获取输入 input</a></span></li><li><span><a href="#练习4" data-toc-modified-id="练习4-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>练习4</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %% [markdown]
# 　　看到这里，我们就已经安装好anaconda，并且学习完anaconda其他组件了，下面我们就介绍一下anaconda最重要的组件，也是今后大家进行python学习和编程的环境：jupyter notebook的常用操作。相信掌握好jupyter notebook的使用，我们在后期学习python时，会如鱼得水。Let`s go!

# %% [markdown]
# <img width = '500' height ='400' src ="https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1547816479309&di=63ee53ec0750d9eee21f848aa6516ef5&imgtype=0&src=http%3A%2F%2Fmmbiz.qpic.cn%2Fmmbiz_gif%2FFCMzv1ttDIDKrvhIDDfAZje5DmBQmTAAMx55LvxXwPsFsIywIxh5y0BRThkqgWsGkiaicaTPFaHm5yVkQ8c9HoeQ%2F640%3Fwx_fmt%3Dgif"/>

# %% [markdown]
# # 前言

# %% [markdown]
# ## Python基础--如何学习
#
#     学习一个新知识之前，先全域的了解知识体系。
#     对整体框架有一定的把我之后，咱们接下需要：
#         - 认真听课
#         - 多敲代码
#         - 多问
#         - 及时复习
#
# ##  为什么学习Python
# &emsp;自2017年AI元年之后，数据领域老大的地位站的不要太稳。
# <br/>&emsp;根据美国电机电子工程师学会(IEEE)发布的《2018年最热门的编程语言》(2018 list of top programming languages)，Python在整体排名中位居榜首。</br>
# <img width = '500' height ='1000' src ="https://5b0988e595225.cdn.sohucs.com/images/20180724/1625cbe584744176b1dfa48b98ebb115.jpeg"/>
# <br/></br>
# ## 为什么数据科学家喜欢用Python？</br>
# ![_auto_1](attachment:_auto_1)

# %% [markdown]
# #  基础知识
# ##  Python概述
# ### Python简史
# - 1989年，Guido Rossum
# - python的创始人为Guido van Rossum。1989年圣诞节期间，在阿姆斯特丹，Guido为了打发圣诞节的无趣，决心开发一个新的脚本解释程序。之所以选中Python（大蟒蛇的意思）作为该编程语言的名字，是因为他是一个叫Monty Python的喜剧团体的爱好者。
# <img width = '300' height ='300' src ="https://ss.csdn.net/p?https://mmbiz.qpic.cn/mmbiz_jpg/Pn4Sm0RsAug0qoIl4FUZp7YGStC9XCyd4JLjeFj9XibicMwhIibP5w5QpUINXM0LRk7MUdDPH8Iibr2883lJYhHuug/640?wx_fmt=jpeg"/>
#
# - 2008年， Python3 诞生
# - 2014年， Python2.7支持到2020
# - 2017年， AI元年，Python崛起
#
#
# ### 环境和版本问题
# - anaconda 3
# - python 3.5.1/3.5.2

# %% [markdown]
# - 今后的学习这几个网站会时常伴随大家：
#
# [python的官网](https://www.python.org)
#
# [anaconda官网](https://www.continuum.io/downloads)
#
# [jupyter notebook 插件](https://github.com/ipython-contrib/jupyter_contrib_nbextensions)

# %% [markdown]
# ### 熟悉代码的运行

# %% [markdown]
# **用快捷键运行下面的代码，作用是：<font color=#DC143C size=2.5 face="黑体">**
# - 设置Jupyter Notebook运行单个cell，能将该cell所有行的结果都输出。
# - 每次打开Jupyter Notebook文件最后都要记得运行下面的代码

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### 练习1

# %% [markdown]
# **尝试敲下面的代码，并观察输出结果：**
#
# **注意：**
# <font color=#DC143C size=2 face="黑体">
# - 所有的符号都需要是英文符号，中文符号会报错
# - 在单元格内输入完代码之后，用快捷键——ctrl+enter，就可以运行单元格内的代码。
# - 如果是按shift+enter，运行完当前单元格代码之后，会自动进入下一个单元格。

# %% [markdown]
#  <font color=#00008B size=3 face="黑体">
#
# **代码一：**

# %% [markdown]
# print("hello world")

# %%
# Out:
# hello world

# %% [markdown]
#  &ensp;
#
#  &ensp;
#   <font color=#00008B size=3 face="黑体">
# **代码二：**

# %% [markdown]
# a = 5
# a
# print(a)

# %%
# Out:
# 5
# 5

# %% [markdown]
#  &ensp;
#
#  &ensp;
#  <font color=#00008B size=3 face="黑体">
# **代码三：**

# %% [markdown]
# print("a=5")

# %%
# Out:
# a=5

# %% [markdown]
#  &ensp;
#
#  &ensp;
# <font color=#00008B size=3 face="黑体">
# **代码四：**

# %% [markdown]
# print("cda")
# print('python')

# %%
# Out:
# cda
# python

# %% [markdown]
# 到这一步，我们其实已经在使用python语言与外部进行交互了。

# %% [markdown]
# &ensp;
#
#
# &ensp;
#
# ## 代码格式

# %% [markdown]
# ###  注释

# %% [markdown]
# - 机器不执行注释内容。
# - 注释一般用自然语言书写。
# - 注释的写法。

# %% [markdown]
# **<font color=#DC143C size=3 face="黑体">单行注释和多行注释的方法：**
# - 在代码的最前面输入井号“#”
# - 选中需要注释的代码，然后按：Ctr+/

# %%
打印一句话

# %%
print('hello world') 这是在打印一句话
# Out:
# hello world

# %% [markdown]
# ### 练习2
# 尝试用单行注释和多行注释的方法操作下面的内容：

# %%
代码作用
1.给人看
2. 给机器看
注释就是给人看的，机器会忽略


这里的任何内容机器都不会读，
我可以写好多好多，
想写多少写多少，
开心就好，
你能拿我怎么样。

# %% [markdown]
# &ensp;
#
#
# &ensp;
# ###  缩进

# %% [markdown]
# - 缩进是python代码最重要的组成部分之一
#     - python用代码区分语句所属代码块
#     - 缩进错误会导致计算机变糊涂，分不清语句所属代码块就会报错
# - 一般是四个空格为一个缩进
#    - python会有强制缩进
#    - 但有时候需要我们手动设置缩进，我们可以用tab键实现

# %%
def Scentances(): 
    print('cda是数据分析领域的非常专业的学校')

# %% [markdown]
# &ensp;
#
# &emsp;
# &ensp;
#
# &emsp;
# ## 内置函数 BIF
# - BIF就是Built-in Function,内置函数的意思。
# - 内置函数是为了方便程序员快速编写程序，
# - Python提供了很丰富的内置函数，只需要直接调用即可

# %% [markdown]
# 既然讲到内置函数，不如先来认识几个常用的吧：
# - print()
# - type()
# - isinstance()

# %%
#查看数据类型：
type('a')
isinstance("a",int)
isinstance("a",str)
# Out:
# str
# False
# True

# %% [markdown]
# ```
#
#
#
# ```
# ### 查看BIF帮助文档

# %% [markdown]
# 查看print()这个BIF的帮助文档，即看看python是怎么给我们解释print()这个内建函数的用法的！有三种方法：
# - $ print(BIF函数名.__doc__) $&ensp; &ensp;&ensp;  &ensp; &ensp; 注意，doc前后各为两条下划线
# - ?BIF函数名()  <font color=#DC143C size=3 face="黑体">  &ensp; &ensp;&ensp; &ensp; &ensp;  &ensp; 直接在内置函数前面加问号 （推荐）<font color=#000000 size=2 face="黑体">
# - help(BIF函数名)     &ensp; &ensp; &ensp; &ensp; 使用内置函数help()查看函数或模块用途的详细说明。

# %% [markdown]
# **比如，如果我们想查看内置函数type()的用法，有以下方法：**

# %%
# ?print

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# &ensp;
#
#
# &ensp;
#
# #  变量

# %%
# 设置全部行输出
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
#  ## 变量的属性
# - 变量就是一个可以重复使用的量，或者叫一个代号
# - 在Python中，不需要先声明变量名及其类型，直接赋值就可以创建各种类型的变量。
# - 变量的命名要遵循以下几条规则：
#     - 只能包含：数字、字母、下划线
#         - 下划线开头有特殊含义，不建议使用
#         - python大小写敏感
#     - 不能：以数字开头、包含空格；
#     - 不能使用python保留字、关键字、函数名
#     - 建议：简短却有描述性、使用小写字母
#     - 慎用：小写字母 l，大写字母 O

# %% [markdown]
# ## 变量的内涵

# %% [markdown]
# **<font color=#00008B size=3.5 face="黑体">
# （1）变量要定义！**

# %%
a

# %%
"a"

# %% [markdown]
# &ensp;
#
#
# &ensp;
# **<font color=#00008B size=3.5 face="黑体">
# （2）变量没有数据类型**

# %% [markdown]
# 变量没有数据类型，但是赋值的数据有

# %%
type('CDA')
# Out:
# str

# %%
aa='CDA'
type(aa)
# Out:
# str

# %% [markdown]
# &ensp;
#
#
# &ensp;
# **<font color=#00008B size=3.5 face="黑体">
# （3）变量可以重复赋值**

# %%
a = 1
a

# %%
a = 10
a

# %% [markdown]
# &ensp;
#
#
# &ensp;
# **<font color=#00008B size=3.5 face="黑体">
# （4）变量相互赋值和运算**

# %%
a=10
b=a
b
# Out:
# 10

# %%
a+b
# Out:
# 20

# %% [markdown]
# &ensp;
#
#
# &ensp;
# **<font color=#00008B size=3.5 face="黑体">
# （5）变量赋值符与判断符**

# %%
a=1
b=1

# %%
b == 1  #变量b指向的内容是否为1
# Out:
# True

# %%
b == a  #两个对象的内容是否相等
# Out:
# True

# %% [markdown]
# &ensp;
#
#
# &ensp;
# **<font color=#00008B size=3.5 face="黑体">
# （6）变量判断符与is运算符**

# %% [markdown]
# 判断符“==”：
# <font color=#DC143C size=2.8 face="黑体">比较的是两个对象的内容（这里的内容是数值）是否相等

# %%
a=1.1
b=1.1

# %%
a==b
# Out:
# True

# %% [markdown]
# is运算符：
# <font color=#DC143C size=2.5 face="黑体">
# 判断a和b是不是同一个对象，占用的**内存地址**是否相同

# %%
a=1.1
b=1.1

# %%
id(a)
id(b)
# Out:
# 1946758709680
# 1946758709584

# %%
a is b
# Out:
# False

# %% [markdown]
# &ensp;
#
# &emsp;
# ## 变量的命名要点

# %% [markdown]
# &ensp;
# &ensp;
# <font color=#00008B size=3.5 face="黑体">
# **（1）常见变量命名误区**

# %%
a=1
A=2

# %%
a
A
# Out:
# 1
# 2

# %% [markdown]
# &ensp;
#
# &ensp;
# <font color=#00008B size=3.5 face="黑体">
# **（2）不要用保留字**
# ```但是要注意：一定不要用python的保留字。他们有专门的意义....
# 下面来看看python都有哪些保留字？```

# %%
import keyword             #python中有keyword这么一个模块，专门用来存储python的保留字
print(keyword.kwlist)      #我们使用print命令就可以将其打印出来
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
False None

# %% [markdown]
# &ensp;
#
# &emsp;

# %% [markdown]
# &ensp;
# &ensp;
# **<font color=#00008B size=3.5 face="黑体">（3）驼峰命名法**
# - 名称以单词自动链接，每个单词的首字母大写
#    - 在python当中给类命名使用此办法
#    - eg： MyFristLove
# - 小驼峰，类似大驼峰，但是第一个字母小写
#    - 在python当中给函数或者普通变量用这个办法：
#    - eg： myLove
# - posix写法：
#    - 多个单词用下划线连接，单词都小写（<font color=#DC143C size=2 face="黑体">**推荐**）
#    - eg： my_love

# %%
my_first_love=aiya

# %% [markdown]
# &ensp;
# &emsp;

# %% [markdown]
# ## 变量赋值
# - 一般情况：=
# - 增量赋值：+=
# - 多重赋值：x=y=z=1
# - 多元赋值：x,y,z=1,2,'a'，*var 收集多余的值
# - 加上括号增加可读性：（x,y,z）=（1,2,'a'）
# - 变量交换：x,y=y,x

# %% [markdown]
# &ensp;
# &ensp;
# <font color=#00008B size=3.5 face="黑体">
# **（1）为多个变量赋值**

# %%
a = b = c = "可以"
a
b
c
# Out:
# '可以'
# '可以'
# '可以'

# %%
e , f, g ="当我", "离开", "你"
g
# Out:
# '你'

# %%
a = 1
b = 2
# python中也可以这样操作
a, b = b, a
print(a, b)
# Out:
# 2 1

# %% [markdown]
# ```
#
#
# ```
#
# # 语句

# %% [markdown]
# ##  print输出
# print 默认输出是换行的.
# <font color=#DC143C size=2.5 face="黑体">
# __注意！正常状态下，一个pint()语句输出一行，将括号内双引号里的字符以打印的形式呈现。__

# %%
print("something")
print("something")
print("something")
# Out:
# something
# something
# something

# %%
print("-"*50)
# Out:
# --------------------------------------------------

# %% [markdown]
# ### 中间分隔符：sep=" "

# %% [markdown]
# 打印多个值,用sep设置中间分隔符, 默认为空格

# %%
print('数据分析', '就业班 ','python')
# Out:
# 数据分析 就业班  python

# %%
print('数据分析', '就业班 ','python', sep='--->')
# Out:
# 数据分析--->就业班 --->python

# %% [markdown]
# ### 结尾换行符:end='' "

# %% [markdown]
# 如果你打印多次，不想一行行打印出来，想都打印在一行，可以在print()后面添加end=""。
# 比如：

# %%
print('我爱北京天安门')
print('天安门上太阳升')
# Out:
# 我爱北京天安门
# 天安门上太阳升

# %%
print('我爱北京天安门', end="")
print('天安门上太阳升')
# Out:
# 我爱北京天安门天安门上太阳升

# %% [markdown]
# &ensp;
#
#
# &ensp;
# **<font color=#DC143C size=3.5 face="黑体">
# 初学的时候，end=""的作用容易和后面的换行符混淆，在这里提前给大家做一个对比：**

# %%
print('我爱北京天安门')
print('天安门上太阳升')
# Out:
# 我爱北京天安门
# 天安门上太阳升

# %%
print('我爱北京天安门\n天安门上太阳升')
# Out:
# 我爱北京天安门
# 天安门上太阳升

# %% [markdown]
# <font color=#DC143C size=3.5 face="黑体">
#
# - end=""讨论的是两个print()以怎样的方式来打印在同一行。
# - 换行符“\n”讨论的一个print()内的字符如何打印在多行。

# %% [markdown]
# ###  练习3

# %% [markdown]
# ***小题1：**
# 将以下字符串打印在同一行，用“——>”符号来分隔：
# "怒发冲冠"、"凭阑处"、"潇潇雨歇"

# %%
print("怒发冲冠",end = "——>")
print("怒发冲冠",end = "——>")
print("怒发冲冠")
# Out:
# 怒发冲冠——>怒发冲冠——>怒发冲冠

# %% [markdown]
# ***小题2：**
# 用一个print()语句，分别将下面字符打印在不同的行：
# "怒发冲冠"、"凭阑处"、"潇潇雨歇"

# %%
print("怒发冲冠",sep="\n")
print("凭阑处",sep="\n")
print("潇潇雨歇")
print("怒发冲冠","凭阑处","潇潇雨歇",sep="\n")
# Out:
# 怒发冲冠
# 凭阑处
# 潇潇雨歇
# 怒发冲冠
# 凭阑处
# 潇潇雨歇

# %% [markdown]
# ***小题3：**
# 在不减少print()语句的前提下，通过增加下面的print()语句的参数，使得打印结果在同一行输出。
# print("怒发冲冠")
# print("凭阑处")
# print("潇潇雨歇")

# %%
print("怒发冲冠",end = "，")
print("凭阑处",end = "，")
print("潇潇雨歇")
# Out:
# 怒发冲冠，凭阑处，潇潇雨歇

# %% [markdown]
# &ensp;
#
# &emsp;
# ## 获取输入 input
# input()语句可以获取一个用户输入的字符串。

# %%
a = input()
# Out:
# 1

# %%
b = input('在这里输入一些字符：')
# Out:
# 在这里输入一些字符：2

# %%
a = input("请输入账号")
b = input("请输入密码")

if a == "123" and b =="1234": 
    print("欢迎用户",a)
elif a == "123" and b !="1234":
    print("密码错误")
else: 
    print("请重新输入")
# Out:
# 请输入账号123
# 请输入密码12345
# 密码错误

# %% [markdown]
# ```
#
#
#
#
#
# ```
# ## 练习4

# %% [markdown]
# 使用imput语句，完成以下任务：
# - 使得用户运行的时候能显示“请输入要打印在屏幕的话”，然后让用户输入。
# - 将用户输入的内容打印出来
